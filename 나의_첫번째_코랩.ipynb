# %% [markdown]
# <a href="https://colab.research.google.com/github/kjjangwon21-web/mn/blob/main/%EB%82%98%EC%9D%98_%EC%B2%AB%EB%B2%88%EC%A7%B8_%EC%BD%94%EB%9E%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #모두의 딥러닝
# ##모두의 딥러닝
# ###모두의 딥러닝

# %%
print("hello world")
# Out:
# hello world

# %%
'''python
print()
print()
print()
'''
# Out:
# 'python\nprint()\nprint()\nprint()\n'

# %% [markdown]
# 2.Tensorflow 모듈 둘러보기

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.19.0'
